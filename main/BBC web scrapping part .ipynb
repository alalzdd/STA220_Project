# %%
import requests
from bs4 import BeautifulSoup
import json
import time
import re
from datetime import datetime

# %%
import requests
from bs4 import BeautifulSoup
import json
import time
import re
from datetime import datetime
import sys

def scrape_bbc_ukraine_war_news(max_pages=1112):
    """
    Scrape BBC news articles about the Ukraine war by iterating through page numbers.

    Args:
        max_pages: Maximum number of pages to scrape (default: 1112 as specified)

    Returns:
        Dictionary with headlines as keys and [date, url] as values
    """
    # Dictionary to store all headlines
    all_headlines = {}

    # Base URL for the search
    base_url = "https://www.bbc.com"

    # Headers to mimic a browser request
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
        'Accept-Language': 'en-US,en;q=0.5',
        'Connection': 'keep-alive',
        'Upgrade-Insecure-Requests': '1',
        'Cache-Control': 'max-age=0'
    }

    # Iterate through pages directly
    for page in range(max_pages + 1):  # +1 to include page 0
        print(f"Scraping page {page}")

        # Construct the URL for the current page
        # Note: We're not using the provided token as it's page-specific and likely expires
        # Instead, we'll use a clean URL and rely on the server to redirect/authenticate
        url = f"{base_url}/search?q=ukraine+war&page={page}"

        try:
            # Make the request to the website
            response = requests.get(url, headers=headers)

            # Check if the page exists
            if response.status_code != 200:
                print(f"Received status code {response.status_code} for page {page}. Stopping.")
                break

            # Parse the HTML content
            soup = BeautifulSoup(response.text, 'html.parser')

            # Find all headlines using the specific CSS selector
            headline_elements = soup.select('#main-content > div.sc-32f23d22-0.heeShB > div > div.sc-32f23d22-2.iumrhG > div > div > div > a > div > div.sc-4ea10043-2.jydkvE > div > div > h2')

            # As a fallback, also try to find elements by data-testid
            if not headline_elements:
                headline_elements = soup.find_all('h2', {'data-testid': 'card-headline'})

            # Check if we found any headlines
            if not headline_elements:
                print(f"No articles found on page {page}. This page might not exist.")

                # If we hit 3 empty pages in a row, assume we've reached the end
                if page > 2:
                    break
                else:
                    continue

            print(f"Found {len(headline_elements)} headlines on page {page}")

            # Extract information from each headline
            for headline_element in headline_elements:
                # Get the headline text
                headline = headline_element.get_text(strip=True)

                # Find the parent article container (going up the DOM tree)
                card = headline_element
                for _ in range(6):  # Go up a few levels to find the container with the link
                    if card.parent:
                        card = card.parent
                    else:
                        break

                # Extract URL
                # Look for an anchor tag within the card element
                link_element = card.find('a')
                if not link_element:
                    continue  # Skip if no link found

                article_url = link_element.get('href')
                if article_url.startswith('/'):
                    article_url = base_url + article_url

                # Extract publication date
                # First try with CSS selector for the date
                date_element = card.select_one('span[data-testid="card-metadata-lastupdated"]')
                if not date_element:
                    # Try alternative selector if needed
                    date_element = card.select_one('.sc-6fba5bd4-1')

                if not date_element:
                    publication_date = "Date not available"
                else:
                    date_text = date_element.get_text(strip=True)
                    # Try to parse and format the date
                    try:
                        # Example formats: "16 Feb 2025", "2 hours ago", "Yesterday"
                        if re.match(r'\d+ \w+ \d{4}', date_text):  # Format: "16 Feb 2025"
                            date_obj = datetime.strptime(date_text, '%d %b %Y')
                            publication_date = date_obj.strftime('%m-%d-%Y')
                        else:
                            publication_date = date_text  # Keep original text for relative dates
                    except Exception as e:
                        publication_date = date_text  # Keep original text if parsing fails

                # Add to our dictionary
                all_headlines[headline] = [publication_date, article_url]

            # Be polite and not overload the server
            time.sleep(2)

        except Exception as e:
            print(f"Error on page {page}: {str(e)}")
            # Continue with the next page instead of breaking
            continue

    return all_headlines

def main():
    print("Starting BBC Ukraine War news scraper...")

    # Set recursion limit higher for complex HTML
    sys.setrecursionlimit(10000)

    # Scrape with the maximum page number specified
    headlines = scrape_bbc_ukraine_war_news(max_pages=1112)

    # Save to JSON file
    with open('bbc_ukraine_war_headlines.json', 'w', encoding='utf-8') as f:
        json.dump(headlines, f, ensure_ascii=False, indent=4)

    print(f"Scraping complete. Found {len(headlines)} headlines.")
    print("Data saved to bbc_ukraine_war_headlines.json")

    # Print a sample of the results
    print("\nResults (first 5 entries):")
    result_sample = dict(list(headlines.items())[:5])
    print(json.dumps(result_sample, ensure_ascii=False, indent=4))
    print(f"... and {len(headlines) - 5} more entries")

if __name__ == "__main__":
    main()
# Out:
# Starting BBC Ukraine War news scraper...
# Scraping page 0
# Found 9 headlines on page 0
# Scraping page 1
# Found 9 headlines on page 1
# Scraping page 2
# Found 9 headlines on page 2
# Scraping page 3
# Found 9 headlines on page 3
# Scraping page 4
# Found 9 headlines on page 4
# Scraping page 5
# Found 9 headlines on page 5
# Scraping page 6
# Found 9 headlines on page 6
# Scraping page 7
# Found 9 headlines on page 7
# Scraping page 8
# Found 9 headlines on page 8
# Scraping page 9
# Found 9 headlines on page 9
# Scraping page 10
# Found 9 headlines on page 10
# Scraping page 11
# Found 9 headlines on page 11
# Scraping page 12
# Found 9 headlines on page 12
# Scraping page 13
# Found 9 headlines on page 13
# Scraping page 14
# Found 9 headlines on page 14
# Scraping page 15
# Found 9 headlines on page 15
# Scraping page 16
# Found 9 headlines on page 16
# Scraping page 17
# Found 9 headlines on page 17
# Scraping page 18
# Found 9 headlines on page 18
# Scraping page 19
# Found 9 headlines on page 19
# Scraping page 20
# Found 9 headlines on page 20
# Scraping page 21
# Found 9 headlines on page 21
# Scraping page 22
# Found 9 headlines on page 22
# Scraping page 23
# Found 9 headlines on page 23
# Scraping page 24
# Found 9 headlines on page 24
# Scraping page 25
# Found 9 headlines on page 25
# Scraping page 26
# Found 9 headlines on page 26
# Scraping page 27
# Found 9 headlines on page 27
# Scraping page 28
# Found 9 headlines on page 28
# Scraping page 29
# Found 9 headlines on page 29
# Scraping page 30
# Found 9 headlines on page 30
# Scraping page 31
# Found 9 headlines on page 31
# Scraping page 32
# Found 9 headlines on page 32
# Scraping page 33
# Found 9 headlines on page 33
# Scraping page 34
# Found 9 headlines on page 34
# Scraping page 35
# Found 9 headlines on page 35
# Scraping page 36
# Found 9 headlines on page 36
# Scraping page 37
# Found 9 headlines on page 37
# Scraping page 38
# Found 9 headlines on page 38
# Scraping page 39
# Found 9 headlines on page 39
# Scraping page 40
# Found 9 headlines on page 40
# Scraping page 41
# Found 9 headlines on page 41
# Scraping page 42
# Found 9 headlines on page 42
# Scraping page 43
# Found 9 headlines on page 43
# Scraping page 44
# Found 9 headlines on page 44
# Scraping page 45
# Found 9 headlines on page 45
# Scraping page 46
# Found 9 headlines on page 46
# Scraping page 47
# Found 9 headlines on page 47
# Scraping page 48
# Found 9 headlines on page 48
# Scraping page 49
# Found 9 headlines on page 49
# Scraping page 50
# Found 9 headlines on page 50
# Scraping page 51
# Found 9 headlines on page 51
# Scraping page 52
# Found 9 headlines on page 52
# Scraping page 53
# Found 9 headlines on page 53
# Scraping page 54
# Found 9 headlines on page 54
# Scraping page 55
# Found 9 headlines on page 55
# Scraping page 56
# Found 9 headlines on page 56
# Scraping page 57
# Found 9 headlines on page 57
# Scraping page 58
# Found 9 headlines on page 58
# Scraping page 59
# Found 9 headlines on page 59
# Scraping page 60
# Found 9 headlines on page 60
# Scraping page 61
# Found 9 headlines on page 61
# Scraping page 62
# Found 9 headlines on page 62
# Scraping page 63
# Found 9 headlines on page 63
# Scraping page 64
# Found 9 headlines on page 64
# Scraping page 65
# Found 9 headlines on page 65
# Scraping page 66
# Found 9 headlines on page 66
# Scraping page 67
# Found 9 headlines on page 67
# Scraping page 68
# Found 9 headlines on page 68
# Scraping page 69
# Found 9 headlines on page 69
# Scraping page 70
# Found 9 headlines on page 70
# Scraping page 71
# Found 9 headlines on page 71
# Scraping page 72
# Found 9 headlines on page 72
# Scraping page 73
# Found 9 headlines on page 73
# Scraping page 74
# Found 9 headlines on page 74
# Scraping page 75
# Found 9 headlines on page 75
# Scraping page 76
# Found 9 headlines on page 76
# Scraping page 77
# Found 9 headlines on page 77
# Scraping page 78
# Found 9 headlines on page 78
# Scraping page 79
# Found 9 headlines on page 79
# Scraping page 80
# Found 9 headlines on page 80
# Scraping page 81
# Found 9 headlines on page 81
# Scraping page 82
# Found 9 headlines on page 82
# Scraping page 83
# Found 9 headlines on page 83
# Scraping page 84
# Found 9 headlines on page 84
# Scraping page 85
# Found 9 headlines on page 85
# Scraping page 86
# Found 9 headlines on page 86
# Scraping page 87
# Found 9 headlines on page 87
# Scraping page 88
# Found 9 headlines on page 88
# Scraping page 89
# Found 9 headlines on page 89
# Scraping page 90
# Found 9 headlines on page 90
# Scraping page 91
# Found 9 headlines on page 91
# Scraping page 92
# Found 9 headlines on page 92
# Scraping page 93
# Found 9 headlines on page 93
# Scraping page 94
# Found 9 headlines on page 94
# Scraping page 95
# Found 9 headlines on page 95
# Scraping page 96
# Found 9 headlines on page 96
# Scraping page 97
# Found 9 headlines on page 97
# Scraping page 98
# Found 9 headlines on page 98
# Scraping page 99
# Found 9 headlines on page 99
# Scraping page 100
# Found 9 headlines on page 100
# Scraping page 101
# Found 9 headlines on page 101
# Scraping page 102
# Found 9 headlines on page 102
# Scraping page 103
# Found 9 headlines on page 103
# Scraping page 104
# Found 9 headlines on page 104
# Scraping page 105
# Found 9 headlines on page 105
# Scraping page 106
# Found 9 headlines on page 106
# Scraping page 107
# Found 9 headlines on page 107
# Scraping page 108
# Found 9 headlines on page 108
# Scraping page 109
# Found 9 headlines on page 109
# Scraping page 110
# Found 9 headlines on page 110
# Scraping page 111
# Found 9 headlines on page 111
# Scraping page 112
# Found 9 headlines on page 112
# Scraping page 113
# Found 9 headlines on page 113
# Scraping page 114
# Found 9 headlines on page 114
# Scraping page 115
# Found 9 headlines on page 115
# Scraping page 116
# Found 9 headlines on page 116
# Scraping page 117
# Found 9 headlines on page 117
# Scraping page 118
# Found 9 headlines on page 118
# Scraping page 119
# Found 9 headlines on page 119
# Scraping page 120
# Found 9 headlines on page 120
# Scraping page 121
# Found 9 headlines on page 121
# Scraping page 122
# Found 9 headlines on page 122
# Scraping page 123
# Found 9 headlines on page 123
# Scraping page 124
# Found 9 headlines on page 124
# Scraping page 125
# Found 9 headlines on page 125
# Scraping page 126
# Found 9 headlines on page 126
# Scraping page 127
# Found 9 headlines on page 127
# Scraping page 128
# Found 9 headlines on page 128
# Scraping page 129
# Found 9 headlines on page 129
# Scraping page 130
# Found 9 headlines on page 130
# Scraping page 131
# Found 9 headlines on page 131
# Scraping page 132
# Found 9 headlines on page 132
# Scraping page 133
# Found 9 headlines on page 133
# Scraping page 134
# Found 9 headlines on page 134
# Scraping page 135
# Found 9 headlines on page 135
# Scraping page 136
# Found 9 headlines on page 136
# Scraping page 137
# Found 9 headlines on page 137
# Scraping page 138
# Found 9 headlines on page 138
# Scraping page 139
# Found 9 headlines on page 139
# Scraping page 140
# Found 9 headlines on page 140
# Scraping page 141
# Found 9 headlines on page 141
# Scraping page 142
# Found 9 headlines on page 142
# Scraping page 143
# Found 9 headlines on page 143
# Scraping page 144
# Found 9 headlines on page 144
# Scraping page 145
# Found 9 headlines on page 145
# Scraping page 146
# Found 9 headlines on page 146
# Scraping page 147
# Found 9 headlines on page 147
# Scraping page 148
# Found 9 headlines on page 148
# Scraping page 149
# Found 9 headlines on page 149
# Scraping page 150
# Found 9 headlines on page 150
# Scraping page 151
# Found 9 headlines on page 151
# Scraping page 152
# Found 9 headlines on page 152
# Scraping page 153
# Found 9 headlines on page 153
# Scraping page 154
# Found 9 headlines on page 154
# Scraping page 155
# Found 9 headlines on page 155
# Scraping page 156
# Found 9 headlines on page 156
# Scraping page 157
# Found 9 headlines on page 157
# Scraping page 158
# Found 9 headlines on page 158
# Scraping page 159
# Found 9 headlines on page 159
# Scraping page 160
# Found 9 headlines on page 160
# Scraping page 161
# Found 9 headlines on page 161
# Scraping page 162
# Found 9 headlines on page 162
# Scraping page 163
# Found 9 headlines on page 163
# Scraping page 164
# Found 9 headlines on page 164
# Scraping page 165
# Found 9 headlines on page 165
# Scraping page 166
# Found 9 headlines on page 166
# Scraping page 167
# Found 9 headlines on page 167
# Scraping page 168
# Found 9 headlines on page 168
# Scraping page 169
# Found 9 headlines on page 169
# Scraping page 170
# Found 9 headlines on page 170
# Scraping page 171
# Found 9 headlines on page 171
# Scraping page 172
# Found 9 headlines on page 172
# Scraping page 173
# Found 9 headlines on page 173
# Scraping page 174
# Found 9 headlines on page 174
# Scraping page 175
# Found 9 headlines on page 175
# Scraping page 176
# Found 9 headlines on page 176
# Scraping page 177
# Found 9 headlines on page 177
# Scraping page 178
# Found 9 headlines on page 178
# Scraping page 179
# Found 9 headlines on page 179
# Scraping page 180
# Found 9 headlines on page 180
# Scraping page 181
# Found 9 headlines on page 181
# Scraping page 182
# Found 9 headlines on page 182
# Scraping page 183
# Found 9 headlines on page 183
# Scraping page 184
# Found 9 headlines on page 184
# Scraping page 185
# Found 9 headlines on page 185
# Scraping page 186
# Found 9 headlines on page 186
# Scraping page 187
# Found 9 headlines on page 187
# Scraping page 188
# Found 9 headlines on page 188
# Scraping page 189
# Found 9 headlines on page 189
# Scraping page 190
# Found 9 headlines on page 190
# Scraping page 191
# Found 9 headlines on page 191
# Scraping page 192
# Found 9 headlines on page 192
# Scraping page 193
# Found 9 headlines on page 193
# Scraping page 194
# Found 9 headlines on page 194
# Scraping page 195
# Found 9 headlines on page 195
# Scraping page 196
# Found 9 headlines on page 196
# Scraping page 197
# Found 9 headlines on page 197
# Scraping page 198
# Found 9 headlines on page 198
# Scraping page 199
# Found 9 headlines on page 199
# Scraping page 200
# Found 9 headlines on page 200
# Scraping page 201
# Found 9 headlines on page 201
# Scraping page 202
# Found 9 headlines on page 202
# Scraping page 203
# Found 9 headlines on page 203
# Scraping page 204
# Found 9 headlines on page 204
# Scraping page 205
# Found 9 headlines on page 205
# Scraping page 206
# Found 9 headlines on page 206
# Scraping page 207
# Found 9 headlines on page 207
# Scraping page 208
# Found 9 headlines on page 208
# Scraping page 209
# Found 9 headlines on page 209
# Scraping page 210
# Found 9 headlines on page 210
# Scraping page 211
# Found 9 headlines on page 211
# Scraping page 212
# Found 9 headlines on page 212
# Scraping page 213
# Found 9 headlines on page 213
# Scraping page 214
# Found 9 headlines on page 214
# Scraping page 215
# Found 9 headlines on page 215
# Scraping page 216
# Found 9 headlines on page 216
# Scraping page 217
# Found 9 headlines on page 217
# Scraping page 218
# Found 9 headlines on page 218
# Scraping page 219
# Found 9 headlines on page 219
# Scraping page 220
# Found 9 headlines on page 220
# Scraping page 221
# Found 9 headlines on page 221
# Scraping page 222
# Found 9 headlines on page 222
# Scraping page 223
# Found 9 headlines on page 223
# Scraping page 224
# Found 9 headlines on page 224
# Scraping page 225
# Found 9 headlines on page 225
# Scraping page 226
# Found 9 headlines on page 226
# Scraping page 227
# Found 9 headlines on page 227
# Scraping page 228
# Found 9 headlines on page 228
# Scraping page 229
# Found 9 headlines on page 229
# Scraping page 230
# Found 9 headlines on page 230
# Scraping page 231
# Found 9 headlines on page 231
# Scraping page 232
# Found 9 headlines on page 232
# Scraping page 233
# Found 9 headlines on page 233
# Scraping page 234
# Found 9 headlines on page 234
# Scraping page 235
# Found 9 headlines on page 235
# Scraping page 236
# Found 9 headlines on page 236
# Scraping page 237
# Found 9 headlines on page 237
# Scraping page 238
# Found 9 headlines on page 238
# Scraping page 239
# Found 9 headlines on page 239
# Scraping page 240
# Found 9 headlines on page 240
# Scraping page 241
# Found 9 headlines on page 241
# Scraping page 242
# Found 9 headlines on page 242
# Scraping page 243
# Found 9 headlines on page 243
# Scraping page 244
# Found 9 headlines on page 244
# Scraping page 245
# Found 9 headlines on page 245
# Scraping page 246
# Found 9 headlines on page 246
# Scraping page 247
# Found 9 headlines on page 247
# Scraping page 248
# Found 9 headlines on page 248
# Scraping page 249
# Found 9 headlines on page 249
# Scraping page 250
# Found 9 headlines on page 250
# Scraping page 251
# Found 9 headlines on page 251
# Scraping page 252
# Found 9 headlines on page 252
# Scraping page 253
# Found 9 headlines on page 253
# Scraping page 254
# Found 9 headlines on page 254
# Scraping page 255
# Found 9 headlines on page 255
# Scraping page 256
# Found 9 headlines on page 256
# Scraping page 257
# Found 9 headlines on page 257
# Scraping page 258
# Found 9 headlines on page 258
# Scraping page 259
# Found 9 headlines on page 259
# Scraping page 260
# Found 9 headlines on page 260
# Scraping page 261
# Found 9 headlines on page 261
# Scraping page 262
# Found 9 headlines on page 262
# Scraping page 263
# Found 9 headlines on page 263
# Scraping page 264
# Found 9 headlines on page 264
# Scraping page 265
# Found 9 headlines on page 265
# Scraping page 266
# Found 9 headlines on page 266
# Scraping page 267
# Found 9 headlines on page 267
# Scraping page 268
# Found 9 headlines on page 268
# Scraping page 269
# Found 9 headlines on page 269
# Scraping page 270
# Found 9 headlines on page 270
# Scraping page 271
# Found 9 headlines on page 271
# Scraping page 272
# Found 9 headlines on page 272
# Scraping page 273
# Found 9 headlines on page 273
# Scraping page 274
# Found 9 headlines on page 274
# Scraping page 275
# Found 9 headlines on page 275
# Scraping page 276
# Found 9 headlines on page 276
# Scraping page 277
# Found 9 headlines on page 277
# Scraping page 278
# Found 9 headlines on page 278
# Scraping page 279
# Found 9 headlines on page 279
# Scraping page 280
# Found 9 headlines on page 280
# Scraping page 281
# Found 9 headlines on page 281
# Scraping page 282
# Found 9 headlines on page 282
# Scraping page 283
# Found 9 headlines on page 283
# Scraping page 284
# Found 9 headlines on page 284
# Scraping page 285
# Found 9 headlines on page 285
# Scraping page 286
# Found 9 headlines on page 286
# Scraping page 287
# Found 9 headlines on page 287
# Scraping page 288
# Found 9 headlines on page 288
# Scraping page 289
# Found 9 headlines on page 289
# Scraping page 290
# Found 9 headlines on page 290
# Scraping page 291
# Found 9 headlines on page 291
# Scraping page 292
# Found 9 headlines on page 292
# Scraping page 293
# Found 9 headlines on page 293
# Scraping page 294
# Found 9 headlines on page 294
# Scraping page 295
# Found 9 headlines on page 295
# Scraping page 296
# Found 9 headlines on page 296
# Scraping page 297
# Found 9 headlines on page 297
# Scraping page 298
# Found 9 headlines on page 298
# Scraping page 299
# Found 9 headlines on page 299
# Scraping page 300
# Found 9 headlines on page 300
# Scraping page 301
# Found 9 headlines on page 301
# Scraping page 302
# Found 9 headlines on page 302
# Scraping page 303
# Found 9 headlines on page 303
# Scraping page 304
# Found 9 headlines on page 304
# Scraping page 305
# Found 9 headlines on page 305
# Scraping page 306
# Found 9 headlines on page 306
# Scraping page 307
# Found 9 headlines on page 307
# Scraping page 308
# Found 9 headlines on page 308
# Scraping page 309
# Found 9 headlines on page 309
# Scraping page 310
# Found 9 headlines on page 310
# Scraping page 311
# Found 9 headlines on page 311
# Scraping page 312
# Found 9 headlines on page 312
# Scraping page 313
# Found 9 headlines on page 313
# Scraping page 314
# Found 9 headlines on page 314
# Scraping page 315
# Found 9 headlines on page 315
# Scraping page 316
# Found 9 headlines on page 316
# Scraping page 317
# Found 9 headlines on page 317
# Scraping page 318
# Found 9 headlines on page 318
# Scraping page 319
# Found 9 headlines on page 319
# Scraping page 320
# Found 9 headlines on page 320
# Scraping page 321
# Found 9 headlines on page 321
# Scraping page 322
# Found 9 headlines on page 322
# Scraping page 323
# Found 9 headlines on page 323
# Scraping page 324
# Found 9 headlines on page 324
# Scraping page 325
# Found 9 headlines on page 325
# Scraping page 326
# Found 9 headlines on page 326
# Scraping page 327
# Found 9 headlines on page 327
# Scraping page 328
# Found 9 headlines on page 328
# Scraping page 329
# Found 9 headlines on page 329
# Scraping page 330
# Found 9 headlines on page 330
# Scraping page 331
# Found 9 headlines on page 331
# Scraping page 332
# Found 9 headlines on page 332
# Scraping page 333
# Found 9 headlines on page 333
# Scraping page 334
# Found 9 headlines on page 334
# Scraping page 335
# Found 9 headlines on page 335
# Scraping page 336
# Found 9 headlines on page 336
# Scraping page 337
# Found 9 headlines on page 337
# Scraping page 338
# Found 9 headlines on page 338
# Scraping page 339
# Found 9 headlines on page 339
# Scraping page 340
# Found 9 headlines on page 340
# Scraping page 341
# Found 9 headlines on page 341
# Scraping page 342
# Found 9 headlines on page 342
# Scraping page 343
# Found 9 headlines on page 343
# Scraping page 344
# Found 9 headlines on page 344
# Scraping page 345
# Found 9 headlines on page 345
# Scraping page 346
# Found 9 headlines on page 346
# Scraping page 347
# Found 9 headlines on page 347
# Scraping page 348
# Found 9 headlines on page 348
# Scraping page 349
# Found 9 headlines on page 349
# Scraping page 350
# Found 9 headlines on page 350
# Scraping page 351
# Found 9 headlines on page 351
# Scraping page 352
# Found 9 headlines on page 352
# Scraping page 353
# Found 9 headlines on page 353
# Scraping page 354
# Found 9 headlines on page 354
# Scraping page 355
# Found 9 headlines on page 355
# Scraping page 356
# Found 9 headlines on page 356
# Scraping page 357
# Found 9 headlines on page 357
# Scraping page 358
# Found 9 headlines on page 358
# Scraping page 359
# Found 9 headlines on page 359
# Scraping page 360
# Found 9 headlines on page 360
# Scraping page 361
# Found 9 headlines on page 361
# Scraping page 362
# Found 9 headlines on page 362
# Scraping page 363
# Found 9 headlines on page 363
# Scraping page 364
# Found 9 headlines on page 364
# Scraping page 365
# Found 9 headlines on page 365
# Scraping page 366
# Found 9 headlines on page 366
# Scraping page 367
# Found 9 headlines on page 367
# Scraping page 368
# Found 9 headlines on page 368
# Scraping page 369
# Found 9 headlines on page 369
# Scraping page 370
# Found 9 headlines on page 370
# Scraping page 371
# Found 9 headlines on page 371
# Scraping page 372
# Found 9 headlines on page 372
# Scraping page 373
# Found 9 headlines on page 373
# Scraping page 374
# Found 9 headlines on page 374
# Scraping page 375
# Found 9 headlines on page 375
# Scraping page 376
# Found 9 headlines on page 376
# Scraping page 377
# Found 9 headlines on page 377
# Scraping page 378
# Found 9 headlines on page 378
# Scraping page 379
# Found 9 headlines on page 379
# Scraping page 380
# Found 9 headlines on page 380
# Scraping page 381
# Found 9 headlines on page 381
# Scraping page 382
# Found 9 headlines on page 382
# Scraping page 383
# Found 9 headlines on page 383
# Scraping page 384
# Found 9 headlines on page 384
# Scraping page 385
# Found 9 headlines on page 385
# Scraping page 386
# Found 9 headlines on page 386
# Scraping page 387
# Found 9 headlines on page 387
# Scraping page 388
# Found 9 headlines on page 388
# Scraping page 389
# Found 9 headlines on page 389
# Scraping page 390
# Found 9 headlines on page 390
# Scraping page 391
# Found 9 headlines on page 391
# Scraping page 392
# Found 9 headlines on page 392
# Scraping page 393
# Found 9 headlines on page 393
# Scraping page 394
# Found 9 headlines on page 394
# Scraping page 395
# Found 9 headlines on page 395
# Scraping page 396
# Found 9 headlines on page 396
# Scraping page 397
# Found 9 headlines on page 397
# Scraping page 398
# Found 9 headlines on page 398
# Scraping page 399
# Found 9 headlines on page 399
# Scraping page 400
# Found 9 headlines on page 400
# Scraping page 401
# Found 9 headlines on page 401
# Scraping page 402
# Found 9 headlines on page 402
# Scraping page 403
# Found 9 headlines on page 403
# Scraping page 404
# Found 9 headlines on page 404
# Scraping page 405
# Found 9 headlines on page 405
# Scraping page 406
# Found 9 headlines on page 406
# Scraping page 407
# Found 9 headlines on page 407
# Scraping page 408
# Found 9 headlines on page 408
# Scraping page 409
# Found 9 headlines on page 409
# Scraping page 410
# Found 9 headlines on page 410
# Scraping page 411
# Found 9 headlines on page 411
# Scraping page 412
# Found 9 headlines on page 412
# Scraping page 413
# Found 9 headlines on page 413
# Scraping page 414
# Found 9 headlines on page 414
# Scraping page 415
# Found 9 headlines on page 415
# Scraping page 416
# Found 9 headlines on page 416
# Scraping page 417
# Found 9 headlines on page 417
# Scraping page 418
# Found 9 headlines on page 418
# Scraping page 419
# Found 9 headlines on page 419
# Scraping page 420
# Found 9 headlines on page 420
# Scraping page 421
# Found 9 headlines on page 421
# Scraping page 422
# Found 9 headlines on page 422
# Scraping page 423
# Found 9 headlines on page 423
# Scraping page 424
# Found 9 headlines on page 424
# Scraping page 425
# Found 9 headlines on page 425
# Scraping page 426
# Found 9 headlines on page 426
# Scraping page 427
# Found 9 headlines on page 427
# Scraping page 428
# Found 9 headlines on page 428
# Scraping page 429
# Found 9 headlines on page 429
# Scraping page 430
# Found 9 headlines on page 430
# Scraping page 431
# Found 9 headlines on page 431
# Scraping page 432
# Found 9 headlines on page 432
# Scraping page 433
# Found 9 headlines on page 433
# Scraping page 434
# Found 9 headlines on page 434
# Scraping page 435
# Found 9 headlines on page 435
# Scraping page 436
# Found 9 headlines on page 436
# Scraping page 437
# Found 9 headlines on page 437
# Scraping page 438
# Found 9 headlines on page 438
# Scraping page 439
# Found 9 headlines on page 439
# Scraping page 440
# Found 9 headlines on page 440
# Scraping page 441
# Found 9 headlines on page 441
# Scraping page 442
# Found 9 headlines on page 442
# Scraping page 443
# Found 9 headlines on page 443
# Scraping page 444
# Found 9 headlines on page 444
# Scraping page 445
# Found 9 headlines on page 445
# Scraping page 446
# Found 9 headlines on page 446
# Scraping page 447
# Found 9 headlines on page 447
# Scraping page 448
# Found 9 headlines on page 448
# Scraping page 449
# Found 9 headlines on page 449
# Scraping page 450
# Found 9 headlines on page 450
# Scraping page 451
# Found 9 headlines on page 451
# Scraping page 452
# Found 9 headlines on page 452
# Scraping page 453
# Found 9 headlines on page 453
# Scraping page 454
# Found 9 headlines on page 454
# Scraping page 455
# Found 9 headlines on page 455
# Scraping page 456
# Found 9 headlines on page 456
# Scraping page 457
# Found 9 headlines on page 457
# Scraping page 458
# Found 9 headlines on page 458
# Scraping page 459
# Found 9 headlines on page 459
# Scraping page 460
# Found 9 headlines on page 460
# Scraping page 461
# Found 9 headlines on page 461
# Scraping page 462
# Found 9 headlines on page 462
# Scraping page 463
# Found 9 headlines on page 463
# Scraping page 464
# Found 9 headlines on page 464
# Scraping page 465
# Found 9 headlines on page 465
# Scraping page 466
# Found 9 headlines on page 466
# Scraping page 467
# Found 9 headlines on page 467
# Scraping page 468
# Found 9 headlines on page 468
# Scraping page 469
# Found 9 headlines on page 469
# Scraping page 470
# Found 9 headlines on page 470
# Scraping page 471
# Found 9 headlines on page 471
# Scraping page 472
# Found 9 headlines on page 472
# Scraping page 473
# Found 9 headlines on page 473
# Scraping page 474
# Found 9 headlines on page 474
# Scraping page 475
# Found 9 headlines on page 475
# Scraping page 476
# Found 9 headlines on page 476
# Scraping page 477
# Found 9 headlines on page 477
# Scraping page 478
# Found 9 headlines on page 478
# Scraping page 479
# Found 9 headlines on page 479
# Scraping page 480
# Found 9 headlines on page 480
# Scraping page 481
# Found 9 headlines on page 481
# Scraping page 482
# Found 9 headlines on page 482
# Scraping page 483
# Found 9 headlines on page 483
# Scraping page 484
# Found 9 headlines on page 484
# Scraping page 485
# Found 9 headlines on page 485
# Scraping page 486
# Found 9 headlines on page 486
# Scraping page 487
# Found 9 headlines on page 487
# Scraping page 488
# Found 9 headlines on page 488
# Scraping page 489
# Found 9 headlines on page 489
# Scraping page 490
# Found 9 headlines on page 490
# Scraping page 491
# Found 9 headlines on page 491
# Scraping page 492
# Found 9 headlines on page 492
# Scraping page 493
# Found 9 headlines on page 493
# Scraping page 494
# Found 9 headlines on page 494
# Scraping page 495
# Found 9 headlines on page 495
# Scraping page 496
# Found 9 headlines on page 496
# Scraping page 497
# Found 9 headlines on page 497
# Scraping page 498
# Found 9 headlines on page 498
# Scraping page 499
# Found 9 headlines on page 499
# Scraping page 500
# Found 9 headlines on page 500
# Scraping page 501
# Found 9 headlines on page 501
# Scraping page 502
# Found 9 headlines on page 502
# Scraping page 503
# Found 9 headlines on page 503
# Scraping page 504
# Found 9 headlines on page 504
# Scraping page 505
# Found 9 headlines on page 505
# Scraping page 506
# Found 9 headlines on page 506
# Scraping page 507
# Found 9 headlines on page 507
# Scraping page 508
# Found 9 headlines on page 508
# Scraping page 509
# Found 9 headlines on page 509
# Scraping page 510
# Found 9 headlines on page 510
# Scraping page 511
# Found 9 headlines on page 511
# Scraping page 512
# Found 9 headlines on page 512
# Scraping page 513
# Found 9 headlines on page 513
# Scraping page 514
# Found 9 headlines on page 514
# Scraping page 515
# Found 9 headlines on page 515
# Scraping page 516
# Found 9 headlines on page 516
# Scraping page 517
# Found 9 headlines on page 517
# Scraping page 518
# Found 9 headlines on page 518
# Scraping page 519
# Found 9 headlines on page 519
# Scraping page 520
# Found 9 headlines on page 520
# Scraping page 521
# Found 9 headlines on page 521
# Scraping page 522
# Found 9 headlines on page 522
# Scraping page 523
# Found 9 headlines on page 523
# Scraping page 524
# Found 9 headlines on page 524
# Scraping page 525
# Found 9 headlines on page 525
# Scraping page 526
# Found 9 headlines on page 526
# Scraping page 527
# Found 9 headlines on page 527
# Scraping page 528
# Found 9 headlines on page 528
# Scraping page 529
# Found 9 headlines on page 529
# Scraping page 530
# Found 9 headlines on page 530
# Scraping page 531
# Found 9 headlines on page 531
# Scraping page 532
# Found 9 headlines on page 532
# Scraping page 533
# Found 9 headlines on page 533
# Scraping page 534
# Found 9 headlines on page 534
# Scraping page 535
# Found 9 headlines on page 535
# Scraping page 536
# Found 9 headlines on page 536
# Scraping page 537
# Found 9 headlines on page 537
# Scraping page 538
# Found 9 headlines on page 538
# Scraping page 539
# Found 9 headlines on page 539
# Scraping page 540
# Found 9 headlines on page 540
# Scraping page 541
# Found 9 headlines on page 541
# Scraping page 542
# Found 9 headlines on page 542
# Scraping page 543
# Found 9 headlines on page 543
# Scraping page 544
# Found 9 headlines on page 544
# Scraping page 545
# Found 9 headlines on page 545
# Scraping page 546
# Found 9 headlines on page 546
# Scraping page 547
# Found 9 headlines on page 547
# Scraping page 548
# Found 9 headlines on page 548
# Scraping page 549
# Found 9 headlines on page 549
# Scraping page 550
# Found 9 headlines on page 550
# Scraping page 551
# Found 9 headlines on page 551
# Scraping page 552
# Found 9 headlines on page 552
# Scraping page 553
# Found 9 headlines on page 553
# Scraping page 554
# Found 9 headlines on page 554
# Scraping page 555
# Found 9 headlines on page 555
# Scraping page 556
# Found 9 headlines on page 556
# Scraping page 557
# Found 9 headlines on page 557
# Scraping page 558
# Found 9 headlines on page 558
# Scraping page 559
# Found 9 headlines on page 559
# Scraping page 560
# Found 9 headlines on page 560
# Scraping page 561
# Found 9 headlines on page 561
# Scraping page 562
# Found 9 headlines on page 562
# Scraping page 563
# Found 9 headlines on page 563
# Scraping page 564
# Found 9 headlines on page 564
# Scraping page 565
# Found 9 headlines on page 565
# Scraping page 566
# Found 9 headlines on page 566
# Scraping page 567
# Found 9 headlines on page 567
# Scraping page 568
# Found 9 headlines on page 568
# Scraping page 569
# Found 9 headlines on page 569
# Scraping page 570
# Found 9 headlines on page 570
# Scraping page 571
# Found 9 headlines on page 571
# Scraping page 572
# Found 9 headlines on page 572
# Scraping page 573
# Found 9 headlines on page 573
# Scraping page 574
# Found 9 headlines on page 574
# Scraping page 575
# Found 9 headlines on page 575
# Scraping page 576
# Found 9 headlines on page 576
# Scraping page 577
# Found 9 headlines on page 577
# Scraping page 578
# Found 9 headlines on page 578
# Scraping page 579
# Found 9 headlines on page 579
# Scraping page 580
# Found 9 headlines on page 580
# Scraping page 581
# Found 9 headlines on page 581
# Scraping page 582
# Found 9 headlines on page 582
# Scraping page 583
# Found 9 headlines on page 583
# Scraping page 584
# Found 9 headlines on page 584
# Scraping page 585
# Found 9 headlines on page 585
# Scraping page 586
# Found 9 headlines on page 586
# Scraping page 587
# Found 9 headlines on page 587
# Scraping page 588
# Found 9 headlines on page 588
# Scraping page 589
# Found 9 headlines on page 589
# Scraping page 590
# Found 9 headlines on page 590
# Scraping page 591
# Found 9 headlines on page 591
# Scraping page 592
# Found 9 headlines on page 592
# Scraping page 593
# Found 9 headlines on page 593
# Scraping page 594
# Found 9 headlines on page 594
# Scraping page 595
# Found 9 headlines on page 595
# Scraping page 596
# Found 9 headlines on page 596
# Scraping page 597
# Found 9 headlines on page 597
# Scraping page 598
# Found 9 headlines on page 598
# Scraping page 599
# Found 9 headlines on page 599
# Scraping page 600
# Found 9 headlines on page 600
# Scraping page 601
# Found 9 headlines on page 601
# Scraping page 602
# Found 9 headlines on page 602
# Scraping page 603
# Found 9 headlines on page 603
# Scraping page 604
# Found 9 headlines on page 604
# Scraping page 605
# Found 9 headlines on page 605
# Scraping page 606
# Found 9 headlines on page 606
# Scraping page 607
# Found 9 headlines on page 607
# Scraping page 608
# Found 9 headlines on page 608
# Scraping page 609
# Found 9 headlines on page 609
# Scraping page 610
# Found 9 headlines on page 610
# Scraping page 611
# Found 9 headlines on page 611
# Scraping page 612
# Found 9 headlines on page 612
# Scraping page 613
# Found 9 headlines on page 613
# Scraping page 614
# Found 9 headlines on page 614
# Scraping page 615
# Found 9 headlines on page 615
# Scraping page 616
# Found 9 headlines on page 616
# Scraping page 617
# Found 9 headlines on page 617
# Scraping page 618
# Found 9 headlines on page 618
# Scraping page 619
# Found 9 headlines on page 619
# Scraping page 620
# Found 9 headlines on page 620
# Scraping page 621
# Found 9 headlines on page 621
# Scraping page 622
# Found 9 headlines on page 622
# Scraping page 623
# Found 9 headlines on page 623
# Scraping page 624
# Found 9 headlines on page 624
# Scraping page 625
# Found 9 headlines on page 625
# Scraping page 626
# Found 9 headlines on page 626
# Scraping page 627
# Found 9 headlines on page 627
# Scraping page 628
# Found 9 headlines on page 628
# Scraping page 629
# Found 9 headlines on page 629
# Scraping page 630
# Found 9 headlines on page 630
# Scraping page 631
# Found 9 headlines on page 631
# Scraping page 632
# Found 9 headlines on page 632
# Scraping page 633
# Found 9 headlines on page 633
# Scraping page 634
# Found 9 headlines on page 634
# Scraping page 635
# Found 9 headlines on page 635
# Scraping page 636
# Found 9 headlines on page 636
# Scraping page 637
# Found 9 headlines on page 637
# Scraping page 638
# Found 9 headlines on page 638
# Scraping page 639
# Found 9 headlines on page 639
# Scraping page 640
# Found 9 headlines on page 640
# Scraping page 641
# Found 9 headlines on page 641
# Scraping page 642
# Found 9 headlines on page 642
# Scraping page 643
# Found 9 headlines on page 643
# Scraping page 644
# Found 9 headlines on page 644
# Scraping page 645
# Found 9 headlines on page 645
# Scraping page 646
# Found 9 headlines on page 646
# Scraping page 647
# Found 9 headlines on page 647
# Scraping page 648
# Found 9 headlines on page 648
# Scraping page 649
# Found 9 headlines on page 649
# Scraping page 650
# Found 9 headlines on page 650
# Scraping page 651
# Found 9 headlines on page 651
# Scraping page 652
# Found 9 headlines on page 652
# Scraping page 653
# Found 9 headlines on page 653
# Scraping page 654
# Found 9 headlines on page 654
# Scraping page 655
# Found 9 headlines on page 655
# Scraping page 656
# Found 9 headlines on page 656
# Scraping page 657
# Found 9 headlines on page 657
# Scraping page 658
# Found 9 headlines on page 658
# Scraping page 659
# Found 9 headlines on page 659
# Scraping page 660
# Found 9 headlines on page 660
# Scraping page 661
# Found 9 headlines on page 661
# Scraping page 662
# Found 9 headlines on page 662
# Scraping page 663
# Found 9 headlines on page 663
# Scraping page 664
# Found 9 headlines on page 664
# Scraping page 665
# Found 9 headlines on page 665
# Scraping page 666
# Found 9 headlines on page 666
# Scraping page 667
# Found 9 headlines on page 667
# Scraping page 668
# Found 9 headlines on page 668
# Scraping page 669
# Found 9 headlines on page 669
# Scraping page 670
# Found 9 headlines on page 670
# Scraping page 671
# Found 9 headlines on page 671
# Scraping page 672
# Found 9 headlines on page 672
# Scraping page 673
# Found 9 headlines on page 673
# Scraping page 674
# Found 9 headlines on page 674
# Scraping page 675
# Found 9 headlines on page 675
# Scraping page 676
# Found 9 headlines on page 676
# Scraping page 677
# Found 9 headlines on page 677
# Scraping page 678
# Found 9 headlines on page 678
# Scraping page 679
# Found 9 headlines on page 679
# Scraping page 680
# Found 9 headlines on page 680
# Scraping page 681
# Found 9 headlines on page 681
# Scraping page 682
# Found 9 headlines on page 682
# Scraping page 683
# Found 9 headlines on page 683
# Scraping page 684
# Found 9 headlines on page 684
# Scraping page 685
# Found 9 headlines on page 685
# Scraping page 686
# Found 9 headlines on page 686
# Scraping page 687
# Found 9 headlines on page 687
# Scraping page 688
# Found 9 headlines on page 688
# Scraping page 689
# Found 9 headlines on page 689
# Scraping page 690
# Found 9 headlines on page 690
# Scraping page 691
# Found 9 headlines on page 691
# Scraping page 692
# Found 9 headlines on page 692
# Scraping page 693
# Found 9 headlines on page 693
# Scraping page 694
# Found 9 headlines on page 694
# Scraping page 695
# Found 9 headlines on page 695
# Scraping page 696
# Found 9 headlines on page 696
# Scraping page 697
# Found 9 headlines on page 697
# Scraping page 698
# Found 9 headlines on page 698
# Scraping page 699
# Found 9 headlines on page 699
# Scraping page 700
# Found 9 headlines on page 700
# Scraping page 701
# Found 9 headlines on page 701
# Scraping page 702
# Found 9 headlines on page 702
# Scraping page 703
# Found 9 headlines on page 703
# Scraping page 704
# Found 9 headlines on page 704
# Scraping page 705
# Found 9 headlines on page 705
# Scraping page 706
# Found 9 headlines on page 706
# Scraping page 707
# Found 9 headlines on page 707
# Scraping page 708
# Found 9 headlines on page 708
# Scraping page 709
# Found 9 headlines on page 709
# Scraping page 710
# Found 9 headlines on page 710
# Scraping page 711
# Found 9 headlines on page 711
# Scraping page 712
# Found 9 headlines on page 712
# Scraping page 713
# Found 9 headlines on page 713
# Scraping page 714
# Found 9 headlines on page 714
# Scraping page 715
# Found 9 headlines on page 715
# Scraping page 716
# Found 9 headlines on page 716
# Scraping page 717
# Found 9 headlines on page 717
# Scraping page 718
# Found 9 headlines on page 718
# Scraping page 719
# Found 9 headlines on page 719
# Scraping page 720
# Found 9 headlines on page 720
# Scraping page 721
# Found 9 headlines on page 721
# Scraping page 722
# Found 9 headlines on page 722
# Scraping page 723
# Found 9 headlines on page 723
# Scraping page 724
# Found 9 headlines on page 724
# Scraping page 725
# Found 9 headlines on page 725
# Scraping page 726
# Found 9 headlines on page 726
# Scraping page 727
# Found 9 headlines on page 727
# Scraping page 728
# Found 9 headlines on page 728
# Scraping page 729
# Found 9 headlines on page 729
# Scraping page 730
# Found 9 headlines on page 730
# Scraping page 731
# Found 9 headlines on page 731
# Scraping page 732
# Found 9 headlines on page 732
# Scraping page 733
# Found 9 headlines on page 733
# Scraping page 734
# Found 9 headlines on page 734
# Scraping page 735
# Found 9 headlines on page 735
# Scraping page 736
# Found 9 headlines on page 736
# Scraping page 737
# Found 9 headlines on page 737
# Scraping page 738
# Found 9 headlines on page 738
# Scraping page 739
# Found 9 headlines on page 739
# Scraping page 740
# Found 9 headlines on page 740
# Scraping page 741
# Found 9 headlines on page 741
# Scraping page 742
# Found 9 headlines on page 742
# Scraping page 743
# Found 9 headlines on page 743
# Scraping page 744
# Found 9 headlines on page 744
# Scraping page 745
# Found 9 headlines on page 745
# Scraping page 746
# Error on page 746: ('Connection broken: IncompleteRead(27560 bytes read, 8113 more expected)', IncompleteRead(27560 bytes read, 8113 more expected))
# Scraping page 747
# Found 9 headlines on page 747
# Scraping page 748
# Found 9 headlines on page 748
# Scraping page 749
# Found 9 headlines on page 749
# Scraping page 750
# Found 9 headlines on page 750
# Scraping page 751
# Found 9 headlines on page 751
# Scraping page 752
# Found 9 headlines on page 752
# Scraping page 753
# Found 9 headlines on page 753
# Scraping page 754
# Found 9 headlines on page 754
# Scraping page 755
# Found 9 headlines on page 755
# Scraping page 756
# Found 9 headlines on page 756
# Scraping page 757
# Found 9 headlines on page 757
# Scraping page 758
# Found 9 headlines on page 758
# Scraping page 759
# Found 9 headlines on page 759
# Scraping page 760
# Found 9 headlines on page 760
# Scraping page 761
# Found 9 headlines on page 761
# Scraping page 762
# Found 9 headlines on page 762
# Scraping page 763
# Found 9 headlines on page 763
# Scraping page 764
# Found 9 headlines on page 764
# Scraping page 765
# Found 9 headlines on page 765
# Scraping page 766
# Found 9 headlines on page 766
# Scraping page 767
# Found 9 headlines on page 767
# Scraping page 768
# Found 9 headlines on page 768
# Scraping page 769
# Found 9 headlines on page 769
# Scraping page 770
# Found 9 headlines on page 770
# Scraping page 771
# Found 9 headlines on page 771
# Scraping page 772
# Found 9 headlines on page 772
# Scraping page 773
# Found 9 headlines on page 773
# Scraping page 774
# Found 9 headlines on page 774
# Scraping page 775
# Found 9 headlines on page 775
# Scraping page 776
# Found 9 headlines on page 776
# Scraping page 777
# Found 9 headlines on page 777
# Scraping page 778
# Found 9 headlines on page 778
# Scraping page 779
# Found 9 headlines on page 779
# Scraping page 780
# Found 9 headlines on page 780
# Scraping page 781
# Found 9 headlines on page 781
# Scraping page 782
# Found 9 headlines on page 782
# Scraping page 783
# Found 9 headlines on page 783
# Scraping page 784
# Found 9 headlines on page 784
# Scraping page 785
# Found 9 headlines on page 785
# Scraping page 786
# Found 9 headlines on page 786
# Scraping page 787
# Found 9 headlines on page 787
# Scraping page 788
# Found 9 headlines on page 788
# Scraping page 789
# Found 9 headlines on page 789
# Scraping page 790
# Found 9 headlines on page 790
# Scraping page 791
# Found 9 headlines on page 791
# Scraping page 792
# Found 9 headlines on page 792
# Scraping page 793
# Found 9 headlines on page 793
# Scraping page 794
# Found 9 headlines on page 794
# Scraping page 795
# Found 9 headlines on page 795
# Scraping page 796
# Found 9 headlines on page 796
# Scraping page 797
# Found 9 headlines on page 797
# Scraping page 798
# Found 9 headlines on page 798
# Scraping page 799
# Found 9 headlines on page 799
# Scraping page 800
# Found 9 headlines on page 800
# Scraping page 801
# Found 9 headlines on page 801
# Scraping page 802
# Found 9 headlines on page 802
# Scraping page 803
# Error on page 803: ('Connection broken: IncompleteRead(27560 bytes read, 7616 more expected)', IncompleteRead(27560 bytes read, 7616 more expected))
# Scraping page 804
# Found 9 headlines on page 804
# Scraping page 805
# Found 9 headlines on page 805
# Scraping page 806
# Found 9 headlines on page 806
# Scraping page 807
# Found 9 headlines on page 807
# Scraping page 808
# Found 9 headlines on page 808
# Scraping page 809
# Found 9 headlines on page 809
# Scraping page 810
# Found 9 headlines on page 810
# Scraping page 811
# Found 9 headlines on page 811
# Scraping page 812
# Found 9 headlines on page 812
# Scraping page 813
# Found 9 headlines on page 813
# Scraping page 814
# Found 9 headlines on page 814
# Scraping page 815
# Found 9 headlines on page 815
# Scraping page 816
# Found 9 headlines on page 816
# Scraping page 817
# Found 9 headlines on page 817
# Scraping page 818
# Found 9 headlines on page 818
# Scraping page 819
# Found 9 headlines on page 819
# Scraping page 820
# Found 9 headlines on page 820
# Scraping page 821
# Found 9 headlines on page 821
# Scraping page 822
# Found 9 headlines on page 822
# Scraping page 823
# Found 9 headlines on page 823
# Scraping page 824
# Found 9 headlines on page 824
# Scraping page 825
# Found 9 headlines on page 825
# Scraping page 826
# Found 9 headlines on page 826
# Scraping page 827
# Found 9 headlines on page 827
# Scraping page 828
# Found 9 headlines on page 828
# Scraping page 829
# Found 9 headlines on page 829
# Scraping page 830
# Found 9 headlines on page 830
# Scraping page 831
# Found 9 headlines on page 831
# Scraping page 832
# Found 9 headlines on page 832
# Scraping page 833
# Found 9 headlines on page 833
# Scraping page 834
# Found 9 headlines on page 834
# Scraping page 835
# Found 9 headlines on page 835
# Scraping page 836
# Found 9 headlines on page 836
# Scraping page 837
# Found 9 headlines on page 837
# Scraping page 838
# Found 9 headlines on page 838
# Scraping page 839
# Found 9 headlines on page 839
# Scraping page 840
# Found 9 headlines on page 840
# Scraping page 841
# Found 9 headlines on page 841
# Scraping page 842
# Found 9 headlines on page 842
# Scraping page 843
# Found 9 headlines on page 843
# Scraping page 844
# Found 9 headlines on page 844
# Scraping page 845
# Found 9 headlines on page 845
# Scraping page 846
# Found 9 headlines on page 846
# Scraping page 847
# Found 9 headlines on page 847
# Scraping page 848
# Found 9 headlines on page 848
# Scraping page 849
# Found 9 headlines on page 849
# Scraping page 850
# Found 9 headlines on page 850
# Scraping page 851
# Found 9 headlines on page 851
# Scraping page 852
# Found 9 headlines on page 852
# Scraping page 853
# Found 9 headlines on page 853
# Scraping page 854
# Found 9 headlines on page 854
# Scraping page 855
# Found 9 headlines on page 855
# Scraping page 856
# Found 9 headlines on page 856
# Scraping page 857
# Found 9 headlines on page 857
# Scraping page 858
# Found 9 headlines on page 858
# Scraping page 859
# Found 9 headlines on page 859
# Scraping page 860
# Found 9 headlines on page 860
# Scraping page 861
# Found 9 headlines on page 861
# Scraping page 862
# Found 9 headlines on page 862
# Scraping page 863
# Found 9 headlines on page 863
# Scraping page 864
# Found 9 headlines on page 864
# Scraping page 865
# Found 9 headlines on page 865
# Scraping page 866
# Found 9 headlines on page 866
# Scraping page 867
# Found 9 headlines on page 867
# Scraping page 868
# Found 9 headlines on page 868
# Scraping page 869
# Found 9 headlines on page 869
# Scraping page 870
# Found 9 headlines on page 870
# Scraping page 871
# Found 9 headlines on page 871
# Scraping page 872
# Found 9 headlines on page 872
# Scraping page 873
# Found 9 headlines on page 873
# Scraping page 874
# Found 9 headlines on page 874
# Scraping page 875
# Found 9 headlines on page 875
# Scraping page 876
# Found 9 headlines on page 876
# Scraping page 877
# Found 9 headlines on page 877
# Scraping page 878
# Found 9 headlines on page 878
# Scraping page 879
# Found 9 headlines on page 879
# Scraping page 880
# Found 9 headlines on page 880
# Scraping page 881
# Found 9 headlines on page 881
# Scraping page 882
# Found 9 headlines on page 882
# Scraping page 883
# Found 9 headlines on page 883
# Scraping page 884
# Found 9 headlines on page 884
# Scraping page 885
# Found 9 headlines on page 885
# Scraping page 886
# Found 9 headlines on page 886
# Scraping page 887
# Found 9 headlines on page 887
# Scraping page 888
# Found 9 headlines on page 888
# Scraping page 889
# Found 9 headlines on page 889
# Scraping page 890
# Found 9 headlines on page 890
# Scraping page 891
# Found 9 headlines on page 891
# Scraping page 892
# Found 9 headlines on page 892
# Scraping page 893
# Found 9 headlines on page 893
# Scraping page 894
# Found 9 headlines on page 894
# Scraping page 895
# Found 9 headlines on page 895
# Scraping page 896
# Found 9 headlines on page 896
# Scraping page 897
# Found 9 headlines on page 897
# Scraping page 898
# Found 9 headlines on page 898
# Scraping page 899
# Found 9 headlines on page 899
# Scraping page 900
# Found 9 headlines on page 900
# Scraping page 901
# Found 9 headlines on page 901
# Scraping page 902
# Found 9 headlines on page 902
# Scraping page 903
# Found 9 headlines on page 903
# Scraping page 904
# Found 9 headlines on page 904
# Scraping page 905
# Found 9 headlines on page 905
# Scraping page 906
# Found 9 headlines on page 906
# Scraping page 907
# Found 9 headlines on page 907
# Scraping page 908
# Found 9 headlines on page 908
# Scraping page 909
# Found 9 headlines on page 909
# Scraping page 910
# Found 9 headlines on page 910
# Scraping page 911
# Found 9 headlines on page 911
# Scraping page 912
# Found 9 headlines on page 912
# Scraping page 913
# Found 9 headlines on page 913
# Scraping page 914
# Found 9 headlines on page 914
# Scraping page 915
# Found 9 headlines on page 915
# Scraping page 916
# Found 9 headlines on page 916
# Scraping page 917
# Found 9 headlines on page 917
# Scraping page 918
# Found 9 headlines on page 918
# Scraping page 919
# Found 9 headlines on page 919
# Scraping page 920
# Found 9 headlines on page 920
# Scraping page 921
# Found 9 headlines on page 921
# Scraping page 922
# Found 9 headlines on page 922
# Scraping page 923
# Found 9 headlines on page 923
# Scraping page 924
# Found 9 headlines on page 924
# Scraping page 925
# Found 9 headlines on page 925
# Scraping page 926
# Found 9 headlines on page 926
# Scraping page 927
# Found 9 headlines on page 927
# Scraping page 928
# Found 9 headlines on page 928
# Scraping page 929
# Found 9 headlines on page 929
# Scraping page 930
# Found 9 headlines on page 930
# Scraping page 931
# Found 9 headlines on page 931
# Scraping page 932
# Found 9 headlines on page 932
# Scraping page 933
# Found 9 headlines on page 933
# Scraping page 934
# Found 9 headlines on page 934
# Scraping page 935
# Found 9 headlines on page 935
# Scraping page 936
# Found 9 headlines on page 936
# Scraping page 937
# Found 9 headlines on page 937
# Scraping page 938
# Found 9 headlines on page 938
# Scraping page 939
# Found 9 headlines on page 939
# Scraping page 940
# Found 9 headlines on page 940
# Scraping page 941
# Found 9 headlines on page 941
# Scraping page 942
# Found 9 headlines on page 942
# Scraping page 943
# Found 9 headlines on page 943
# Scraping page 944
# Found 9 headlines on page 944
# Scraping page 945
# Found 9 headlines on page 945
# Scraping page 946
# Found 9 headlines on page 946
# Scraping page 947
# Found 9 headlines on page 947
# Scraping page 948
# Found 9 headlines on page 948
# Scraping page 949
# Found 9 headlines on page 949
# Scraping page 950
# Found 9 headlines on page 950
# Scraping page 951
# Found 9 headlines on page 951
# Scraping page 952
# Found 9 headlines on page 952
# Scraping page 953
# Found 9 headlines on page 953
# Scraping page 954
# Found 9 headlines on page 954
# Scraping page 955
# Found 9 headlines on page 955
# Scraping page 956
# Found 9 headlines on page 956
# Scraping page 957
# Found 9 headlines on page 957
# Scraping page 958
# Found 9 headlines on page 958
# Scraping page 959
# Found 9 headlines on page 959
# Scraping page 960
# Found 9 headlines on page 960
# Scraping page 961
# Found 9 headlines on page 961
# Scraping page 962
# Found 9 headlines on page 962
# Scraping page 963
# Found 9 headlines on page 963
# Scraping page 964
# Found 9 headlines on page 964
# Scraping page 965
# Found 9 headlines on page 965
# Scraping page 966
# Found 9 headlines on page 966
# Scraping page 967
# Found 9 headlines on page 967
# Scraping page 968
# Found 9 headlines on page 968
# Scraping page 969
# Found 9 headlines on page 969
# Scraping page 970
# Found 9 headlines on page 970
# Scraping page 971
# Found 9 headlines on page 971
# Scraping page 972
# Found 9 headlines on page 972
# Scraping page 973
# Found 9 headlines on page 973
# Scraping page 974
# Found 9 headlines on page 974
# Scraping page 975
# Found 9 headlines on page 975
# Scraping page 976
# Found 9 headlines on page 976
# Scraping page 977
# Found 9 headlines on page 977
# Scraping page 978
# Found 9 headlines on page 978
# Scraping page 979
# Found 9 headlines on page 979
# Scraping page 980
# Found 9 headlines on page 980
# Scraping page 981
# Found 9 headlines on page 981
# Scraping page 982
# Found 9 headlines on page 982
# Scraping page 983
# Found 9 headlines on page 983
# Scraping page 984
# Found 9 headlines on page 984
# Scraping page 985
# Found 9 headlines on page 985
# Scraping page 986
# Found 9 headlines on page 986
# Scraping page 987
# Found 9 headlines on page 987
# Scraping page 988
# Found 9 headlines on page 988
# Scraping page 989
# Found 9 headlines on page 989
# Scraping page 990
# Found 9 headlines on page 990
# Scraping page 991
# Found 9 headlines on page 991
# Scraping page 992
# Found 9 headlines on page 992
# Scraping page 993
# Found 9 headlines on page 993
# Scraping page 994
# Found 9 headlines on page 994
# Scraping page 995
# Found 9 headlines on page 995
# Scraping page 996
# Found 9 headlines on page 996
# Scraping page 997
# Found 9 headlines on page 997
# Scraping page 998
# Found 9 headlines on page 998
# Scraping page 999
# Found 9 headlines on page 999
# Scraping page 1000
# Found 9 headlines on page 1000
# Scraping page 1001
# Found 9 headlines on page 1001
# Scraping page 1002
# Found 9 headlines on page 1002
# Scraping page 1003
# Found 9 headlines on page 1003
# Scraping page 1004
# Found 9 headlines on page 1004
# Scraping page 1005
# Found 9 headlines on page 1005
# Scraping page 1006
# Found 9 headlines on page 1006
# Scraping page 1007
# Found 9 headlines on page 1007
# Scraping page 1008
# Found 9 headlines on page 1008
# Scraping page 1009
# Found 9 headlines on page 1009
# Scraping page 1010
# Found 9 headlines on page 1010
# Scraping page 1011
# Found 9 headlines on page 1011
# Scraping page 1012
# Found 9 headlines on page 1012
# Scraping page 1013
# Found 9 headlines on page 1013
# Scraping page 1014
# Found 9 headlines on page 1014
# Scraping page 1015
# Found 9 headlines on page 1015
# Scraping page 1016
# Found 9 headlines on page 1016
# Scraping page 1017
# Found 9 headlines on page 1017
# Scraping page 1018
# Found 9 headlines on page 1018
# Scraping page 1019
# Found 9 headlines on page 1019
# Scraping page 1020
# Found 9 headlines on page 1020
# Scraping page 1021
# Found 9 headlines on page 1021
# Scraping page 1022
# Found 9 headlines on page 1022
# Scraping page 1023
# Found 9 headlines on page 1023
# Scraping page 1024
# Found 9 headlines on page 1024
# Scraping page 1025
# Found 9 headlines on page 1025
# Scraping page 1026
# Found 9 headlines on page 1026
# Scraping page 1027
# Found 9 headlines on page 1027
# Scraping page 1028
# Found 9 headlines on page 1028
# Scraping page 1029
# Found 9 headlines on page 1029
# Scraping page 1030
# Found 9 headlines on page 1030
# Scraping page 1031
# Found 9 headlines on page 1031
# Scraping page 1032
# Found 9 headlines on page 1032
# Scraping page 1033
# Found 9 headlines on page 1033
# Scraping page 1034
# Found 9 headlines on page 1034
# Scraping page 1035
# Found 9 headlines on page 1035
# Scraping page 1036
# Found 9 headlines on page 1036
# Scraping page 1037
# Found 9 headlines on page 1037
# Scraping page 1038
# Found 9 headlines on page 1038
# Scraping page 1039
# Found 9 headlines on page 1039
# Scraping page 1040
# Found 9 headlines on page 1040
# Scraping page 1041
# Found 9 headlines on page 1041
# Scraping page 1042
# Found 9 headlines on page 1042
# Scraping page 1043
# Found 9 headlines on page 1043
# Scraping page 1044
# Found 9 headlines on page 1044
# Scraping page 1045
# Found 9 headlines on page 1045
# Scraping page 1046
# Found 9 headlines on page 1046
# Scraping page 1047
# Found 9 headlines on page 1047
# Scraping page 1048
# Found 9 headlines on page 1048
# Scraping page 1049
# Found 9 headlines on page 1049
# Scraping page 1050
# Found 9 headlines on page 1050
# Scraping page 1051
# Found 9 headlines on page 1051
# Scraping page 1052
# Found 9 headlines on page 1052
# Scraping page 1053
# Found 9 headlines on page 1053
# Scraping page 1054
# Found 9 headlines on page 1054
# Scraping page 1055
# Found 9 headlines on page 1055
# Scraping page 1056
# Found 9 headlines on page 1056
# Scraping page 1057
# Found 9 headlines on page 1057
# Scraping page 1058
# Found 9 headlines on page 1058
# Scraping page 1059
# Found 9 headlines on page 1059
# Scraping page 1060
# Found 9 headlines on page 1060
# Scraping page 1061
# Found 9 headlines on page 1061
# Scraping page 1062
# Found 9 headlines on page 1062
# Scraping page 1063
# Found 9 headlines on page 1063
# Scraping page 1064
# Found 9 headlines on page 1064
# Scraping page 1065
# Found 9 headlines on page 1065
# Scraping page 1066
# Found 9 headlines on page 1066
# Scraping page 1067
# Found 9 headlines on page 1067
# Scraping page 1068
# Found 9 headlines on page 1068
# Scraping page 1069
# Found 9 headlines on page 1069
# Scraping page 1070
# Found 9 headlines on page 1070
# Scraping page 1071
# Found 9 headlines on page 1071
# Scraping page 1072
# Found 9 headlines on page 1072
# Scraping page 1073
# Found 9 headlines on page 1073
# Scraping page 1074
# Found 9 headlines on page 1074
# Scraping page 1075
# Found 9 headlines on page 1075
# Scraping page 1076
# Found 9 headlines on page 1076
# Scraping page 1077
# Found 9 headlines on page 1077
# Scraping page 1078
# Found 9 headlines on page 1078
# Scraping page 1079
# Found 9 headlines on page 1079
# Scraping page 1080
# Found 9 headlines on page 1080
# Scraping page 1081
# Found 9 headlines on page 1081
# Scraping page 1082
# Found 9 headlines on page 1082
# Scraping page 1083
# Found 9 headlines on page 1083
# Scraping page 1084
# Found 9 headlines on page 1084
# Scraping page 1085
# Found 9 headlines on page 1085
# Scraping page 1086
# Found 9 headlines on page 1086
# Scraping page 1087
# Found 9 headlines on page 1087
# Scraping page 1088
# Found 9 headlines on page 1088
# Scraping page 1089
# Found 9 headlines on page 1089
# Scraping page 1090
# Found 9 headlines on page 1090
# Scraping page 1091
# Found 9 headlines on page 1091
# Scraping page 1092
# Found 9 headlines on page 1092
# Scraping page 1093
# Found 9 headlines on page 1093
# Scraping page 1094
# Found 9 headlines on page 1094
# Scraping page 1095
# Found 9 headlines on page 1095
# Scraping page 1096
# Found 9 headlines on page 1096
# Scraping page 1097
# Found 9 headlines on page 1097
# Scraping page 1098
# Found 9 headlines on page 1098
# Scraping page 1099
# Found 9 headlines on page 1099
# Scraping page 1100
# Found 9 headlines on page 1100
# Scraping page 1101
# Found 9 headlines on page 1101
# Scraping page 1102
# Found 9 headlines on page 1102
# Scraping page 1103
# Found 9 headlines on page 1103
# Scraping page 1104
# Found 9 headlines on page 1104
# Scraping page 1105
# Found 9 headlines on page 1105
# Scraping page 1106
# Found 9 headlines on page 1106
# Scraping page 1107
# Found 9 headlines on page 1107
# Scraping page 1108
# Found 9 headlines on page 1108
# Scraping page 1109
# Found 9 headlines on page 1109
# Scraping page 1110
# Found 9 headlines on page 1110
# Scraping page 1111
# Found 1 headlines on page 1111
# Scraping page 1112
# Received status code 500 for page 1112. Stopping.
# Scraping complete. Found 8388 headlines.
# Data saved to bbc_ukraine_war_headlines.json
#
# Results (first 5 entries):
# {
#     "Hundreds gather at Ukraine war vigil": [
#         "7 days ago",
#         "https://www.bbc.com/news/articles/cqlyrkgkde5o"
#     ],
#     "Ukraine war: US-Russia peace talks": [
#         "02-19-2025",
#         "https://www.bbc.com/audio/play/p0ks6jlm"
#     ],
#     "Performance marks third anniversary of Ukraine war": [
#         "5 days ago",
#         "https://www.bbc.com/news/articles/c778jm8pm4eo"
#     ],
#     "Diplomacy gathers pace over war in Ukraine": [
#         "02-16-2025",
#         "https://www.bbc.com/audio/play/p0krp07v"
#     ],
#     "Fact-checking Trump claims about war in Ukraine": [
#         "02-19-2025",
#         "https://www.bbc.com/news/articles/c9814k2jlxko"
#     ]
# }
# ... and 8383 more entries

# %%
import json
import pandas as pd
import csv
from google.colab import files
import os

# First, let's make sure the JSON file exists
try:
    # Open the JSON file
    with open('bbc_ukraine_war_headlines.json', 'r', encoding='utf-8') as file:
        data = json.load(file)

    print(f"Successfully loaded JSON file with {len(data)} headlines")

    # Convert the JSON structure to a format suitable for CSV
    # The JSON is in format: {"headline": ["date", "url"], ...}
    csv_data = []
    for headline, details in data.items():
        # Extract date and URL from the details array
        if len(details) >= 2:
            date, url = details[0], details[1]
        else:
            # Handle cases where the details array might not have both elements
            date = details[0] if len(details) > 0 else "No date"
            url = details[1] if len(details) > 1 else "No URL"

        # Add to the list of rows
        csv_data.append({
            "Headline": headline,
            "Date": date,
            "URL": url
        })

    # Create a DataFrame
    df = pd.DataFrame(csv_data)

    # Save to CSV
    csv_filename = 'bbc_ukraine_war_headlines.csv'
    df.to_csv(csv_filename, index=False, encoding='utf-8-sig')  # utf-8-sig for Excel compatibility

    print(f"Successfully converted to CSV with {len(df)} rows")

    # Download both files
    print("Downloading files...")
    files.download('bbc_ukraine_war_headlines.json')
    files.download(csv_filename)

    print("Files downloaded successfully!")

    # Print a sample of the data
    print("\nSample of the CSV data (first 5 rows):")
    print(df.head())

except FileNotFoundError:
    print("Error: The file 'bbc_ukraine_war_headlines.json' was not found.")
    print("Make sure you ran the scraper first and the file was created successfully.")

except Exception as e:
    print(f"An error occurred: {str(e)}")
# Out:
# Successfully loaded JSON file with 8388 headlines
# Successfully converted to CSV with 8388 rows
# Downloading files...
# Files downloaded successfully!
#
# Sample of the CSV data (first 5 rows):
#                                             Headline        Date  \
# 0               Hundreds gather at Ukraine war vigil  7 days ago
# 1                 Ukraine war: US-Russia peace talks  02-19-2025
# 2  Performance marks third anniversary of Ukraine...  5 days ago
# 3         Diplomacy gathers pace over war in Ukraine  02-16-2025
# 4    Fact-checking Trump claims about war in Ukraine  02-19-2025
#
#                                               URL
# 0  https://www.bbc.com/news/articles/cqlyrkgkde5o
# 1         https://www.bbc.com/audio/play/p0ks6jlm
# 2  https://www.bbc.com/news/articles/c778jm8pm4eo
# 3         https://www.bbc.com/audio/play/p0krp07v
# 4  https://www.bbc.com/news/articles/c9814k2jlxko
